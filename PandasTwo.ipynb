# %% [markdown]
# ### Data Analysis with Pandas - II

# %%
'''
> Perform Column operations: Performing Artimetic & Text Operations to a column
> Perform Column operations: Apply a function to a specific column.
> Adding Fields & Records.
> Perform Column operations: Renaming the Column names.
> Summarization (Eg. Avg, Count, Median, Unique) ; Pivot Tables, GROUP BY **
> Sort the DataFrames (Eg. Sorting by ASC, DESC)
> Indexing the DataFrames - Slicing the DataFrames**
> Creating a DataFrame using 2D Lists
    - Understand the concept of Indexes, Columns
> JOINS & CONCAT (Eg. Merging & Appending two or more DataFrames) **
> Handling Missing Values
> Deleting the Fields & Records **

'''

# %%
import pandas as pd

# %%
df = pd.read_csv('OrangeQ.csv')

# %%
df.head(10)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
# 5       6.7        126              9.1          3.0            2.0
# 6       7.2        160              9.0          3.5            3.5
# 7       6.5        130             13.5          2.8            1.5
# 8       8.8        240              7.5          4.0            5.0
# 9       7.8        190             12.0          3.1            2.0
#
#    HarvestTime(days)  Ripeness(1-5)          Color           Variety  \
# 0                 10            4.0         Orange          Valencia
# 1                 14            4.5    Deep Orange             Navel
# ...

# %%
df['Status'] = 'Pending'

# %%
df.head(10)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
# 5       6.7        126              9.1          3.0            2.0
# 6       7.2        160              9.0          3.5            3.5
# 7       6.5        130             13.5          2.8            1.5
# 8       8.8        240              7.5          4.0            5.0
# 9       7.8        190             12.0          3.1            2.0
#
#    HarvestTime(days)  Ripeness(1-5)          Color           Variety  \
# 0                 10            4.0         Orange          Valencia
# 1                 14            4.5    Deep Orange             Navel
# ...

# %%
df['row_id'] = [i for i in range(1,df.shape[0]+1)]

# %%
df.tail(10)
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 231       9.5        131              6.1          3.3            5.0
# 232       6.1        273              8.3          4.3            1.0
# 233       8.2        249             12.8          3.8            3.0
# 234       8.6        251             11.5          3.8            5.0
# 235       8.5        130              8.1          3.6            3.0
# 236       8.0        194             10.9          3.6            5.0
# 237       7.4        275              8.5          3.5            5.0
# 238       7.5        196             15.7          3.0            3.0
# 239       7.2        251              9.8          4.3            3.0
# 240       7.3        282             10.5          2.9            4.0
#
#      HarvestTime(days)  Ripeness(1-5)         Color            Variety  \
# 231                 21            2.0  Light Orange          Star Ruby
# ...

# %%
df.sample(20)
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 202       7.2        299             12.7         4.30            5.0
# 222       9.4        291              6.3         3.90            4.0
# 226       7.6        100             14.5         3.10            5.0
# 219       6.6        267             12.5         4.00            5.0
# 69        7.9        190             11.0         3.20            2.0
# 78        8.6        225             12.5         3.10            2.5
# 15        6.3        120             14.5         2.90            1.0
# 139       6.0        157              9.2         3.85            1.0
# 49        7.2        160             11.5         3.20            2.0
# 2         6.8        150             14.0         3.00            1.0
# 73        7.5        175             10.0         3.30            2.5
# 163       9.0        126             11.5         4.30            3.0
# ...

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)   Status  row_id
# 0              N           4.0  Pending       1
# 1              N           4.5  Pending       2
# ...

# %%
df.columns
# Out:
# Index(['Size(cm)', 'Weight(g)', 'Brix(Sweetness)', 'pH(Acidity)',
#        'Softness(1-5)', 'HarvestTime(days)', 'Ripeness(1-5)', 'Color',
#        'Variety', 'Blemishes(Y/N)', 'Quality(1-5)', 'Status', 'row_id'],
#       dtype='object')

# %%
df['SampleTest'] = df['Size(cm)'] * df['Weight(g)']

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)   Status  row_id  SampleTest
# 0              N           4.0  Pending       1      1350.0
# ...

# %%
df['StringTest'] = df['Color'] + "-" + df['Variety']

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)   Status  row_id  SampleTest  \
# 0              N           4.0  Pending       1      1350.0
# ...

# %%
df['StringTest'] = df['StringTest'].str.upper()

# %%
df['StringTest2'] = df['Color'].str.split("-")

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)   Status  row_id  SampleTest  \
# 0              N           4.0  Pending       1      1350.0
# ...

# %%
def orangeStatus(blemishes):

    if blemishes == "N":

        return "Approved"
    
    else:

        return "Pending"

# %%
orangeStatus('E')
# Out:
# 'Pending'

# %%
df['Status'] = df['Blemishes(Y/N)'].apply(orangeStatus)

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)    Status  row_id  SampleTest  \
# 0              N           4.0  Approved       1      1350.0
# ...

# %%
# df.rename(columns={'Size(cm)': 'size'})

# %%
df.columns
# Out:
# Index(['Size(cm)', 'Weight(g)', 'Brix(Sweetness)', 'pH(Acidity)',
#        'Softness(1-5)', 'HarvestTime(days)', 'Ripeness(1-5)', 'Color',
#        'Variety', 'Blemishes(Y/N)', 'Quality(1-5)', 'Status', 'row_id',
#        'SampleTest', 'StringTest', 'StringTest2', 'StringTest3'],
#       dtype='object')

# %%
old_names = ['Size(cm)', 'Weight(g)', 'Brix(Sweetness)', 'pH(Acidity)',
       'Softness(1-5)', 'HarvestTime(days)', 'Ripeness(1-5)', 'Color',
       'Variety', 'Blemishes(Y/N)', 'Quality(1-5)', 'Status', 'row_id',
       'SampleTest', 'StringTest', 'StringTest2', 'StringTest3']

# %%
names = {col : col.lower().replace("_td", "") for col in df.columns}

df.rename(columns=names)
# Out:
#      size(cm)  weight(g)  brix(sweetness)  ph(acidity)  softness(1-5)  \
# 0         7.5        180             12.0          3.2            2.0
# 1         8.2        220             10.5          3.4            3.0
# 2         6.8        150             14.0          3.0            1.0
# 3         9.0        250              8.5          3.8            4.0
# 4         8.5        210             11.5          3.3            2.5
# ..        ...        ...              ...          ...            ...
# 236       8.0        194             10.9          3.6            5.0
# 237       7.4        275              8.5          3.5            5.0
# 238       7.5        196             15.7          3.0            3.0
# 239       7.2        251              9.8          4.3            3.0
# 240       7.3        282             10.5          2.9            4.0
#
#      harvesttime(days)  ripeness(1-5)         color            variety  \
# ...

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)    Status  row_id  SampleTest  \
# 0              N           4.0  Approved       1      1350.0
# ...

# %%
df.groupby('Color')['Weight(g)'].mean()
# Out:
# Color
# Deep Orange      208.973333
# Light Orange     191.375000
# Orange           206.763158
# Orange-Red       221.872727
# Yellow-Orange    161.666667
# Name: Weight(g), dtype: float64

# %%
df.groupby(['Color', 'Variety'])[['Weight(g)', 'Size(cm)']].mean()
# Out:
#                                     Weight(g)  Size(cm)
# Color         Variety
# Deep Orange   Ambiance             202.000000  7.100000
#               California Valencia  180.000000  7.600000
#               Cara Cara            197.000000  8.250000
#               Clementine           230.500000  7.250000
#               Hamlin               190.000000  7.800000
# ...                                       ...       ...
# Orange-Red    Washington Navel     132.500000  7.850000
# Yellow-Orange Jaffa                170.000000  7.400000
#               Minneola (Hybrid)    148.750000  7.075000
#               Ortanique (Hybrid)   176.666667  7.533333
#               Tangelo (Hybrid)     160.000000  7.200000
#
# [68 rows x 2 columns]

# %%
df.groupby(['Color', 'Variety'])[['Weight(g)', 'Size(cm)']].count()
# Out:
#                                    Weight(g)  Size(cm)
# Color         Variety
# Deep Orange   Ambiance                     3         3
#               California Valencia          3         3
#               Cara Cara                    2         2
#               Clementine                   6         6
#               Hamlin                       1         1
# ...                                      ...       ...
# Orange-Red    Washington Navel             2         2
# Yellow-Orange Jaffa                        1         1
#               Minneola (Hybrid)            4         4
#               Ortanique (Hybrid)           3         3
#               Tangelo (Hybrid)             1         1
#
# [68 rows x 2 columns]

# %%
df.sort_values('Size(cm)', ascending=False)
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 20       10.0        300              7.0         4.10            5.0
# 53        9.9        290              5.5         4.40            5.0
# 207       9.9        169             12.8         3.70            1.0
# 110       9.9        152              6.4         3.33            4.0
# 23        9.8        280              6.5         4.30            5.0
# ..        ...        ...              ...          ...            ...
# 214       6.1        233             10.9         3.00            5.0
# 180       6.1        198              9.0         3.10            4.0
# 51        6.1        105             14.0         2.90            1.0
# 139       6.0        157              9.2         3.85            1.0
# 71        6.0        100             14.5         2.80            1.0
#
#      HarvestTime(days)  Ripeness(1-5)         Color             Variety  \
# ...

# %%
df.head(5)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)    Status  row_id  SampleTest  \
# 0              N           4.0  Approved       1      1350.0
# ...

# %%
'''

Difference Between Loc & iLoc

Iloc - Used to slice the dataframe with the col indexes passed as integer values 

df.iloc[row_start_index: row_end_index, col_start_index: col_end_index]


Loc:  Used to slice the dataframe with the col names passed as string values 

df.loc[row_start_index: row_end_index, col_start_index: col_end_index]


'''

df.iloc[10:20, 3:8]
# Out:
#     pH(Acidity)  Softness(1-5)  HarvestTime(days)  Ripeness(1-5)  \
# 10          4.2            4.5                 24            2.5
# 11          3.7            2.0                 12            3.0
# 12          3.5            3.0                 13            4.0
# 13          3.2            2.5                  8            4.5
# 14          3.7            4.5                 20            4.0
# 15          2.9            1.0                  6            5.0
# 16          3.9            3.5                 17            3.5
# 17          4.2            4.0                 11            1.0
# 18          3.3            4.0                 24            5.0
# 19          3.0            2.0                 10            4.0
#
#             Color
# 10     Orange-Red
# 11    Deep Orange
# 12         Orange
# 13    Deep Orange
# 14     Orange-Red
# 15   Light Orange
# 16         Orange
# 17    Deep Orange
# 18   Light Orange
# 19  Yellow-Orange

# %%
df.iloc[:2, :2]
# Out:
#    Size(cm)  Weight(g)
# 0       7.5        180
# 1       8.2        220

# %%
df.loc[:3, 'Size(cm)': 'pH(Acidity)']
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)
# 0       7.5        180             12.0          3.2
# 1       8.2        220             10.5          3.4
# 2       6.8        150             14.0          3.0
# 3       9.0        250              8.5          3.8

# %%
'''

Orange Supplier Details

Columns: Supplier ID, Farm Name, Supplier Location, Supplier Email


'''

# %%
'''

1D List: [1,2,3,4]

2D List [[1,2,3], 
        [1,2,3], 
        [1,2,3]]

'''

# %%
supplierData =[[1, 'Greenbay Farms', 'Keene', 'info@greenbay.com'],
               [2, ' NH Farms', 'Laconia', 'info@Laconia.com'],
               [3, ' Fresh Today', 'Hampton', 'info@ft.com'],
               [4, ' Luke Farms', 'Conway', 'info@lukefarms.com']
                ]

# %%
supplierData
# Out:
# [[1, 'Greenbay Farms', 'Keene', 'info@greenbay.com'],
#  [2, ' NH Farms', 'Laconia', 'info@Laconia.com'],
#  [3, ' Fresh Today', 'Hampton', 'info@ft.com'],
#  [4, ' Luke Farms', 'Conway', 'info@lukefarms.com']]

# %%
supplier = pd.DataFrame(data=supplierData, columns=['id', 'name', 'location', 'email'], index=["S" + str(i) for i in range(1,5)])

# %%
supplier
# Out:
#     id            name location               email
# S1   1  Greenbay Farms    Keene   info@greenbay.com
# S2   2        NH Farms  Laconia    info@Laconia.com
# S3   3     Fresh Today  Hampton         info@ft.com
# S4   4      Luke Farms   Conway  info@lukefarms.com

# %%
supplier.loc["S2":, : "location"]
# Out:
#     id          name location
# S2   2      NH Farms  Laconia
# S3   3   Fresh Today  Hampton
# S4   4    Luke Farms   Conway

# %%
import random

# %%
random.randint(1,5)
# Out:
# 4

# %%
import numpy as np

# %%
np.random.randint(1,5)
# Out:
# 2

# %%
import numpy as np

id = []
for i in range(1,242):

    id.append(np.random.randint(1,5))

# %%
id
# Out:
# [1,
#  2,
#  3,
#  3,
#  3,
#  4,
#  4,
#  3,
#  4,
#  4,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  4,
#  3,
#  2,
#  3,
#  1,
#  1,
#  4,
#  4,
#  1,
#  3,
#  2,
#  4,
#  3,
#  3,
#  1,
#  2,
#  1,
#  1,
#  2,
#  3,
#  3,
#  1,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  3,
#  4,
#  4,
#  4,
#  4,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  4,
#  4,
#  2,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  2,
#  3,
#  1,
#  4,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  4,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  4,
#  3,
#  2,
#  1,
#  2,
#  3,
#  1,
#  1,
#  4,
#  3,
#  2,
#  1,
#  2,
#  4,
#  3,
#  1,
#  4,
#  1,
#  4,
#  2,
#  4,
#  3,
#  2,
#  3,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  3,
#  4,
#  3,
#  3,
#  4,
#  1,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  3,
#  4,
#  1,
#  3,
#  1,
# ...

# %%
df.shape[0]
# Out:
# 241

# %%
df['supplier_id'] = id

# %%
df.rename(columns={'supplier_id': 'id'}, inplace=True)

# %%
df.head(10)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
# 5       6.7        126              9.1          3.0            2.0
# 6       7.2        160              9.0          3.5            3.5
# 7       6.5        130             13.5          2.8            1.5
# 8       8.8        240              7.5          4.0            5.0
# 9       7.8        190             12.0          3.1            2.0
#
#    HarvestTime(days)  Ripeness(1-5)          Color           Variety  \
# 0                 10            4.0         Orange          Valencia
# 1                 14            4.5    Deep Orange             Navel
# ...

# %%
df.merge(supplier, how='left', on='id')
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0         7.5        180             12.0          3.2            2.0
# 1         8.2        220             10.5          3.4            3.0
# 2         6.8        150             14.0          3.0            1.0
# 3         9.0        250              8.5          3.8            4.0
# 4         8.5        210             11.5          3.3            2.5
# ..        ...        ...              ...          ...            ...
# 236       8.0        194             10.9          3.6            5.0
# 237       7.4        275              8.5          3.5            5.0
# 238       7.5        196             15.7          3.0            3.0
# 239       7.2        251              9.8          4.3            3.0
# 240       7.3        282             10.5          2.9            4.0
#
#      HarvestTime(days)  Ripeness(1-5)         Color            Variety  \
# ...

# %%
df.fillna('Invalid', inplace=True)

# %%
df
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0         7.5        180             12.0          3.2            2.0
# 1         8.2        220             10.5          3.4            3.0
# 2         6.8        150             14.0          3.0            1.0
# 3         9.0        250              8.5          3.8            4.0
# 4         8.5        210             11.5          3.3            2.5
# ..        ...        ...              ...          ...            ...
# 236       8.0        194             10.9          3.6            5.0
# 237       7.4        275              8.5          3.5            5.0
# 238       7.5        196             15.7          3.0            3.0
# 239       7.2        251              9.8          4.3            3.0
# 240       7.3        282             10.5          2.9            4.0
#
#      HarvestTime(days)  Ripeness(1-5)         Color            Variety  \
# ...

# %%
df.columns
# Out:
# Index(['Size(cm)', 'Weight(g)', 'Brix(Sweetness)', 'pH(Acidity)',
#        'Softness(1-5)', 'HarvestTime(days)', 'Ripeness(1-5)', 'Color',
#        'Variety', 'Blemishes(Y/N)', 'Quality(1-5)', 'Status', 'row_id',
#        'SampleTest', 'StringTest', 'StringTest2', 'StringTest3', 'id'],
#       dtype='object')

# %%
df.drop(['row_id','SampleTest', 'StringTest', 'StringTest2', 'StringTest3'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
# 5       6.7        126              9.1          3.0            2.0
# 6       7.2        160              9.0          3.5            3.5
# 7       6.5        130             13.5          2.8            1.5
# 8       8.8        240              7.5          4.0            5.0
# 9       7.8        190             12.0          3.1            2.0
#
#    HarvestTime(days)  Ripeness(1-5)          Color           Variety  \
# 0                 10            4.0         Orange          Valencia
# 1                 14            4.5    Deep Orange             Navel
# ...

# %%
supplier.drop('S4', axis=0)
# Out:
#     id            name location              email
# S1   1  Greenbay Farms    Keene  info@greenbay.com
# S2   2        NH Farms  Laconia   info@Laconia.com
# S3   3     Fresh Today  Hampton        info@ft.com

# %%
pd.concat([supplier, supplier, supplier], axis=1)
# Out:
#     id            name location               email  id            name  \
# S1   1  Greenbay Farms    Keene   info@greenbay.com   1  Greenbay Farms
# S2   2        NH Farms  Laconia    info@Laconia.com   2        NH Farms
# S3   3     Fresh Today  Hampton         info@ft.com   3     Fresh Today
# S4   4      Luke Farms   Conway  info@lukefarms.com   4      Luke Farms
#
#    location               email  id            name location  \
# S1    Keene   info@greenbay.com   1  Greenbay Farms    Keene
# S2  Laconia    info@Laconia.com   2        NH Farms  Laconia
# S3  Hampton         info@ft.com   3     Fresh Today  Hampton
# S4   Conway  info@lukefarms.com   4      Luke Farms   Conway
#
#                  email
# S1   info@greenbay.com
# S2    info@Laconia.com
# S3         info@ft.com
# S4  info@lukefarms.com
