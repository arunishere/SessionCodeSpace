# %% [markdown]
# ### Data Analysis with Pandas - I

# %%
'''
> Advanced Excel -- > SQL -- > Power BI -- > Pandas in Python
> Working with Tables (Rows & Columns) ; Structured Data
> Acessing the Table (Looking the Rows & Columns)
    - Records: Rows ; Fields: Columns
    - Look at the table dimentions ; Dimention: ROWS x COLUMNS (Eg. 1000 x 10 )
    - Select specific columns & Select All the columns
    - Select specific rows (Filtering the data)
    - Limiting data for a specific limit
> Aggregate Column Functions (Eg. COUNT, MIN, MAX, SUM.. etc)
> Summarization (Eg. Avg, Count, Median, Unique) ; Pivot Tables, GROUP BY
> Adding Fields & Records
> Deleting the Fields & Records

> DataFrame: Table


'''

# %%
import pandas as pd

# %%
df = pd.read_csv('OrangeQ.csv')

# %%
df
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0         7.5        180             12.0          3.2            2.0
# 1         8.2        220             10.5          3.4            3.0
# 2         6.8        150             14.0          3.0            1.0
# 3         9.0        250              8.5          3.8            4.0
# 4         8.5        210             11.5          3.3            2.5
# ..        ...        ...              ...          ...            ...
# 236       8.0        194             10.9          3.6            5.0
# 237       7.4        275              8.5          3.5            5.0
# 238       7.5        196             15.7          3.0            3.0
# 239       7.2        251              9.8          4.3            3.0
# 240       7.3        282             10.5          2.9            4.0
#
#      HarvestTime(days)  Ripeness(1-5)         Color            Variety  \
# ...

# %%
df.head()
# Out:
#    Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0       7.5        180             12.0          3.2            2.0
# 1       8.2        220             10.5          3.4            3.0
# 2       6.8        150             14.0          3.0            1.0
# 3       9.0        250              8.5          3.8            4.0
# 4       8.5        210             11.5          3.3            2.5
#
#    HarvestTime(days)  Ripeness(1-5)         Color       Variety  \
# 0                 10            4.0        Orange      Valencia
# 1                 14            4.5   Deep Orange         Navel
# 2                  7            5.0  Light Orange     Cara Cara
# 3                 21            3.5    Orange-Red  Blood Orange
# 4                 12            5.0        Orange        Hamlin
#
#   Blemishes(Y/N)  Quality(1-5)
# 0              N           4.0
# 1              N           4.5
# 2              N           5.0
# 3              N           3.5
# ...

# %%
df.shape
# Out:
# 11

# %%
df.columns
# Out:
# Index(['Size(cm)', 'Weight(g)', 'Brix(Sweetness)', 'pH(Acidity)',
#        'Softness(1-5)', 'HarvestTime(days)', 'Ripeness(1-5)', 'Color',
#        'Variety', 'Blemishes(Y/N)', 'Quality(1-5)'],
#       dtype='object')

# %%
df2 = df[['Size(cm)', 'Weight(g)','Color','Variety']]

# %%
df[['Weight(g)']]
# Out:
#      Weight(g)
# 0          180
# 1          220
# 2          150
# 3          250
# 4          210
# ..         ...
# 236        194
# 237        275
# 238        196
# 239        251
# 240        282
#
# [241 rows x 1 columns]

# %%
df_orange = df[df['Color']=='Orange']

# %%
df_orange.shape
# Out:
# (38, 11)

# %%
df[(df['Color']=='Orange') & (df['Variety']=='Hamlin')]
# Out:
#     Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 4        8.5        210             11.5          3.3            2.5
# 30       8.3        220             11.0          3.3            3.0
# 47       8.2        215             10.0          3.4            3.0
# 62       8.0        200             10.5          3.3            3.0
#
#     HarvestTime(days)  Ripeness(1-5)   Color Variety Blemishes(Y/N)  \
# 4                  12            5.0  Orange  Hamlin      Y (Minor)
# 30                 15            4.0  Orange  Hamlin              N
# 47                 14            4.0  Orange  Hamlin              N
# 62                 12            4.0  Orange  Hamlin              N
#
#     Quality(1-5)
# 4            4.5
# 30           4.5
# 47           4.5
# 62           4.5

# %%
df[(df['Color']=='Orange') | (df['Color']=='Light Orange')]
# Out:
#      Size(cm)  Weight(g)  Brix(Sweetness)  pH(Acidity)  Softness(1-5)  \
# 0         7.5        180             12.0          3.2            2.0
# 2         6.8        150             14.0          3.0            1.0
# 4         8.5        210             11.5          3.3            2.5
# 5         6.7        126              9.1          3.0            2.0
# 7         6.5        130             13.5          2.8            1.5
# ..        ...        ...              ...          ...            ...
# 231       9.5        131              6.1          3.3            5.0
# 232       6.1        273              8.3          4.3            1.0
# 235       8.5        130              8.1          3.6            3.0
# 237       7.4        275              8.5          3.5            5.0
# 239       7.2        251              9.8          4.3            3.0
#
#      HarvestTime(days)  Ripeness(1-5)         Color            Variety  \
# ...

# %%
df['Weight(g)'].sum()
# Out:
# 49.436
